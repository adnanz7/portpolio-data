# %% [markdown]
# # Data Jadwal UAS Perkuliah Saya

# %%
import pandas as pd

jadwal = pd.read_excel('Jadwal UAS1 - Python.xlsx', names = ['Hari', 'Tanggal', 'Jam', 'Kode', 'Mata Kuliah', 'SKS', 'Kelas', 'Jurusan', 'Dosen', 'Metode'])
jadwal
# Out:
#       Hari    Tanggal            Jam    Kode          Mata Kuliah  SKS  Kelas  \
# 0    SENIN 2021-12-06  08.00 - 10.00  EAK311  Pengantar Akuntansi    4  21AK2
# 1    SENIN 2021-12-06  08.00 - 10.00  EAK311  Pengantar Akuntansi    4  21AK3
# 2    SENIN 2021-12-06  08.00 - 10.00  EAK311  Pengantar Akuntansi    4  21AK4
# 3    SENIN 2021-12-06  08.00 - 09.30  EIE705      Ekonomi Syariah    3  20MN3
# 4    SENIN 2021-12-06  08.00 - 09.30  EIE705      Ekonomi Syariah    3  20MN2
# ..     ...        ...            ...     ...                  ...  ...    ...
# 174  JUMAT 2021-12-10  13.30 - 14.30  UBB104       Bahasa Inggris    2  21AK3
# 175  JUMAT 2021-12-10  13.30 - 14.30  UBB104       Bahasa Inggris    2  21AK4
# 176  JUMAT 2021-12-10  13.30 - 14.30  UBB104       Bahasa Inggris    2  21MN1
# 177  JUMAT 2021-12-10  13.30 - 14.30  UBB104       Bahasa Inggris    2  21MN2
# 178  JUMAT 2021-12-10  13.30 - 14.30  UBB104       Bahasa Inggris    2  21MN3
#
# ...

# %% [markdown]
# ## Tampilkan Jadwal Kelas 19PMS dan 19MN2

# %%
jadwal.set_index('Kelas', inplace = True)
jadwal.loc[['19MN2', '19PMS'], :]
# Out:
#          Hari    Tanggal            Jam    Kode  \
# Kelas
# 19MN2   SENIN 2021-12-06  10.00 - 11.30  EMA220
# 19MN2  SELASA 2021-12-07  10.00 - 11.30  EMA111
# 19PMS   SENIN 2021-12-06  13.00 - 14.30  EMA315
# 19PMS  SELASA 2021-12-07  13.00 - 14.30  EMA317
# 19PMS    RABU 2021-12-08  10.00 - 11.30  EMA226
# 19PMS    RABU 2021-12-08  13.00 - 14.30  EMA123
# 19PMS   KAMIS 2021-12-09  08.00 - 09.30  EMA412
# 19PMS   KAMIS 2021-12-09  13.00 - 14.30  EMA225
#
#                              Mata Kuliah  SKS    Jurusan  \
# Kelas
# 19MN2  Manajemen Inovasi dan Kreativitas    3  Manajemen
# 19MN2           Metode Penelitian Bisnis    3  Manajemen
# 19PMS                Pemasaran Strategik    3  Manajemen
# 19PMS                     Pemasaran Jasa    3  Manajemen
# 19PMS                    Riset Pemasaran    3  Manajemen
# 19PMS                  Perilaku Konsumen    3  Manajemen
# 19PMS                  Digital Marketing    3  Manajemen
# ...
